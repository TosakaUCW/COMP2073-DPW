# %%
import pandas as pd

s = pd.Series([10, 20, 30], index=['a','b','c'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s[0:2]
# Out:
# a    10
# b    20
# dtype: int64

# %%
x = 0
y = 2
s[x:y]
# Out:
# a    10
# b    20
# dtype: int64

# %%
s['a':'b']
# Out:
# a    10
# b    20
# dtype: int64

# %%
df = pd.DataFrame({
    'name': ['Alice','Bob'],
    'age': [25, 30]
}, index=['r1','r2'])

# %%
df
# Out:
#      name  age
# r1  Alice   25
# r2    Bob   30

# %%
df['name']
# Out:
# r1    Alice
# r2      Bob
# Name: name, dtype: object
