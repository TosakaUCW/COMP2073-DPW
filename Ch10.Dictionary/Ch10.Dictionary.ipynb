# %%
NAME = "Bohan YANG"
StudentID = "2330016056"

# %% [markdown]
# ---

# %% [markdown]
# # Python Dictionary
#
# *© 2018-current, authors at Computer Science and Technology, Division of Science and Technology, BNU-HKBU United International College*
#
# A dictionary is like an address-book where you can find the address or contact details of a person by knowing only their name, i.e. we associate **keys** (name) with **values** (details).
#
#
# ## 1. Ceate Dictionary
#
# To create a dictionary, you may place all the dictionary items inside a pair of curly brackets ({}), separated by commas. Follows are some notes about the declaration of a dictionary.
#
# * Every item is defined by a *key* and a *value*, separated by a colon (:).
# * You can use **only immutable objects (like strings) for the keys**.
# * The keys must be **unique**.
# * You can use either immutable or mutable objects for the values of the dictionary.

# %%
# This creates an empty dictionary
dic = {}

# This creates a dictionary, the names are the "keys", and the emails are the "values".
dic = {'Alice':'alice@uic.edu.hk', 'Bob':'bob@uic.edu.hk'}

# This creates a dictionary with mixed keys
my_dict = {'name': 'John', 1: [1, 2, 3]}#

# This creates a dictionary from a sequence having each item as a pair
my_dict = dict([(1,'apple'), (2,'pineapple')])

# In this example, the two pairs have the same key 'Alice'
# The second pair is not added into the dictionary as a new pair
# Instead, it is used to update the first pair, so there will be only one pair in the dictionary
dic = {'Alice':'alice@uic.edu.hk', 'Alice':'ali@uic.edu.hk'}
print(dic)
# Out:
# {'Alice': 'ali@uic.edu.hk'}

# %%
# This raises a TypeError, since key ['Alice'] is mutable.
dic = {['Alice']:'alice@uic.edu.hk', 'Bob':'bob@uic.edu.hk'}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # This raises a TypeError, since key ['Alice'] is mutable.
# ----> 2 dic = {['Alice']:'alice@uic.edu.hk', 'Bob':'bob@uic.edu.hk'}
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# ## 2. Access Values in Dictionary
#
# There are two ways to get the values in a dictionary.
#
# * Use the key as the index. If the key does not exist in the dictionary, a KeyError will be raised.

# %%
dic = {'Alice':'alice@uic.edu.hk', 'Bob':'bob@uic.edu.hk'}

# This prints the value of key 'Bob'
print(dic['Bob'])

# Key 'Cici' is not in the dictionary, this causes a KeyError
print(dic['Cici'])
# Out:
# bob@uic.edu.hk
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 7
#       4 print(dic['Bob'])
#       6 # Key 'Cici' is not in the dictionary, this causes a KeyError
# ----> 7 print(dic['Cici'])
#
# KeyError: 'Cici'

# %% [markdown]
# * Use the `get()` method. If the key does not exist in the dictionary, a default value will be returned.

# %%
# Key 'Cici' is not in the dictionary, so None will be returned by default
print(dic.get('Cici'))

# You can set the default value for the non-existant keys
print(dic.get('Cici', 'Mail not found'))
# Out:
# None
# Mail not found

# %% [markdown]
# ## 3. Change or Add Dictionary Elements
#
# Dictionaries are *mutable*. We can add new items or change the value of existing items using an assignment operator.
#
# If the key is already present, then the existing value gets updated. In case the key is not present, a new `key: value` pair is added to the dictionary.

# %%
# Changing and adding Dictionary Elements
dic = {'Alice':'alice@uic.edu.hk', 'Bob':'bob@uic.edu.hk'}

# update value
dic['Alice'] = 'alice@uic.edu.cn'
print(dic)

# add item
dic['Cici'] = 'cici@uic.edu.cn'
print(dic)
# Out:
# {'Alice': 'alice@uic.edu.cn', 'Bob': 'bob@uic.edu.hk'}
# {'Alice': 'alice@uic.edu.cn', 'Bob': 'bob@uic.edu.hk', 'Cici': 'cici@uic.edu.cn'}

# %% [markdown]
# **Task 1:** Complete the function `counter` that accepts a sentence and returns a dictionary which counts the number of occurrence for each word in the sentence. To be specific, the key for the dictionary is a word and its value is the number of occurrence of the word.
#
# Note that the sentence may contain punctuations including `','`, `'.'`, and `':'`, but they should not be considered during counting. Further, the counter is case insensitive and every word in the dictionary should be in all lower case.
#
# For example, `counter('Good good study, day day up.')` should return `{'good':2, 'study':1, 'day':2, 'up':1}`.

# %%
def counter(sentence):
    buk = {}
    sentence = sentence.lower()
    s = ""
    punctuation = ",.:"
    for ch in sentence:
        if ch not in punctuation:
            s += ch
    s = s.split()
    for x in s:
        if x in buk:
            buk[x] += 1
        else:
            buk[x] = 1
    return buk

# %%
assert counter('Good good study, day day up.') == {'good':2, 'study':1, 'day':2, 'up':1}
assert counter('NO: means no.') == {'no':2, 'means': 1}
assert counter('') == {}

# %%
# This cell contains hidden tests. Do NOT delete!

# %%
# This cell contains hidden tests. Do NOT delete!

# %% [markdown]
# **Task 2:** Complete the function `getdict` that accepts a list of tuples and each tuple contains a person's age information: `(name, age)`. The function returns a dictionary containing all the `name: age` pairs.
#
# Note that it is possible that two people have the same name. In this case, the first people keeps their original name, and the later names get suffix `'1'`, `'2'`, `'3'`, and so on. All the tuples should be in the dictionary.
#
# For example, `getdict([('Ann', 21), ('Ann', 22), ('Ann', 23), ('Bob', 20)])` should return `{'Ann': 21, 'Ann1': 22, 'Ann2': 23, 'Bob': 20}`

# %%
def getdict(tuples):
    result = {}
    name_count = {}
    
    for name, age in tuples:
        if name not in result:  
            result[name] = age
            name_count[name] = 1
        else:
            new_name = name + str(name_count[name])
            result[new_name] = age
            name_count[name] += 1  # 计数加 1

    return result

# %%
assert getdict([('Ann', 21), ('Ann', 22), ('Ann', 23), ('Bob', 20)]) == {'Ann': 21, 'Ann1': 22, 'Ann2': 23, 'Bob': 20}
assert getdict([('Ann', 20), ('Ann', 20), ('Bob', 21), ('Bob', 21)]) == {'Ann': 20, 'Ann1': 20, 'Bob': 21, 'Bob1': 21}
assert getdict([('Ann', 21)]) == {'Ann': 21}
assert getdict([]) == {}

# %%
# This cell contains hidden tests. Do NOT delete!

# %%
# This cell contains hidden tests. Do NOT delete!

# %% [markdown]
# ## 4. Remove Elements from Dictionary
# There are at least 4 ways that we can remove elements from a dictionary.
#
# * Use the `pop()` method. Given a `key`, it removes the element with the key and returns its `value`.
# * Use the `popitem()` method to remove and return the item that was last inserted (since Python 3.7) into the dictionary.
# * Use the `clear()` method to empty the dictionary.
# * Use the `del` keyword to remove individual items or the entire dictionary itself.

# %%
dic = {'Alice':'alice@uic.edu.hk', 'Bob':'bob@uic.edu.hk', 'Cici':'cici@uic.edu.hk', 'Dan':'dan@uic.edu.hk'}

# This removes the element with key 'Alice'
print(dic.pop('Alice'))
print(dic)

# This removes a random element
print(dic.popitem())
print(dic)

# This removes all the elements
# The dictionary is empty but it is still there
dic.clear()
print(dic)

# This destroys the dictionary entirely
# After del, trying to access dic will raise a NameError
del dic
print(dic)
# Out:
# alice@uic.edu.hk
# {'Bob': 'bob@uic.edu.hk', 'Cici': 'cici@uic.edu.hk', 'Dan': 'dan@uic.edu.hk'}
# ('Dan', 'dan@uic.edu.hk')
# {'Bob': 'bob@uic.edu.hk', 'Cici': 'cici@uic.edu.hk'}
# {}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 19
#      16 # This destroys the dictionary entirely
#      17 # After del, trying to access dic will raise a NameError
#      18 del dic
# ---> 19 print(dic)
#
# NameError: name 'dic' is not defined

# %% [markdown]
# **Task 3:** Complete the funtion `updatedict` that takes two arguments: a dictionary containing people names with their public keys, and a list of people names whose public keys have expired. The function should update expired public keys to `"EXPIRED"`.
#
# Note that it is possible that the name in the expire list does not exist in the dictionary. In that case, nothing is done to the dictionary.

# %%
def updatedict(publickeys, expired):
    for x in expired:
        if x in publickeys:
            publickeys[x] = 'EXPIRED'

# %%
pkeys = {'Ann':'FDFJDS42389s', 'Bin': '0X0JDS42387D', 'Cat': '2cIJDS42eW9k'}
updatedict(pkeys, ['Ann', 'Bin', 'Cat'])
assert pkeys == {'Ann':'EXPIRED', 'Bin': 'EXPIRED', 'Cat': 'EXPIRED'}

pkeys = {'Ann':'FDFJDS42389s', 'Bin': '0X0JDS42387D', 'Cat': '2cIJDS42eW9k'}
updatedict(pkeys, ['Ann', 'Bob'])
assert pkeys == {'Ann':'EXPIRED', 'Bin': '0X0JDS42387D', 'Cat': '2cIJDS42eW9k'}

pkeys = {'Ann':'FDFJDS42389s', 'Bin': '0X0JDS42387D', 'Cat': '2cIJDS42eW9k'}
updatedict(pkeys, [])
assert pkeys == {'Ann':'FDFJDS42389s', 'Bin': '0X0JDS42387D', 'Cat': '2cIJDS42eW9k'}

# %%
# This cell contains hidden tests. Do NOT delete!

# %%
# This cell contains hidden tests. Do NOT delete!

# %% [markdown]
# ##  5. Dictionary Methods
#
# Methods that are available with a dictionary are listed below. You may check [here](https://www.programiz.com/python-programming/methods/dictionary) for further details.
#
# |Method|Description|
# | ---  | --- |
# |clear()|Removes all items from the dictionary.|
# |copy()|Returns a shallow copy of the dictionary.|
# |fromkeys(seq[, v])|Returns a new dictionary with keys from `seq` and value equal to `v` (defaults to `None`).|
# |get(key[,d])|Returns the value of the `key`. If the `key` does not exist, returns `d` (defaults to `None`).|
# |items()|Return a new object of the dictionary's items in (key, value) format.|
# |keys()|Returns a new object of the dictionary's keys.|
# |pop(key[,d])|Removes the item with the `key` and returns its value or `d` if `key` is not found. If `d` is not provided and the `key` is not found, it raises `KeyError`.|
# |popitem()|Removes and returns an arbitrary item *(key, value)*. Raises `KeyError` if the dictionary is empty.|
# |setdefault(key[,d])|Returns the corresponding value if the `key` is in the dictionary. If not, inserts the `key` with a value of `d` and returns `d` (defaults to `None`).|
# |update([other])|Updates the dictionary with the key/value pairs from `other`, overwriting existing keys.|
# |values()|Returns a new object of the dictionary's values|

# %% [markdown]
# ## 6. Dictionary Build-in Functions
# Built-in functions like are commonly used with dictionaries to perform different tasks. Below is a list of them.
#
# |Function|Description|
# |---|---|
# |all()|Return `True` if all keys of the dictionary are True (or if the dictionary is empty).|
# |any()|Return `True` if any key of the dictionary is true. If the dictionary is empty, return `False`.|
# |len()|Return the length (the number of items) in the dictionary.|
# |cmp()|Compares items of two dictionaries. (Not available in Python 3)|
# |sorted()|Return a new sorted list of keys in the dictionary.|

# %% [markdown]
# ## 7. Dictionary Comprehensions
#
# Dictionary comprehension is an elegant and concise way to create a new dictionary from an iterable in Python. Its syntax is similar to that of a list comprehension.
#
# ### 7.1 Advantage of Using Dictionary Comprehension
#
# Using dictionary comprehension in our code can shorten the lines of code while keeping the logic intact.
#
#
# A very common task in Python is to take some kind of sequential data and then turn it into a dictionary. Say, for example, that we wanted to take a list of strings and then create a dictionary mapping the strings to their lengths.
#
# **Example:** Record the `province name: name length` pair for the province(s) whose name length is longer than 7.

# %%
china_provinces = ["GuangDong", "YunNan", "HuBei", "ShanDong", "ZheJiang", "JiangSu", "LiaoNing", "HeiLongJiang"]

# solution 1 using loops
dic_province = {}
for item in china_provinces:
    if len(item) > 7:
        dic_province[item] = len(item)
print (dic_province)

# solution 2 using list comprehension
china_provinces_tuples = [(item, len(item)) for item in china_provinces if len(item)>7]
dic_province = dict(china_provinces_tuples)
print (dic_province)

# solution 3 using dictionary comprehension
dic_province = {item: len(item) for item in china_provinces if len(item)>7}
print (dic_province)
# Out:
# {'GuangDong': 9, 'ShanDong': 8, 'ZheJiang': 8, 'LiaoNing': 8, 'HeiLongJiang': 12}
# {'GuangDong': 9, 'ShanDong': 8, 'ZheJiang': 8, 'LiaoNing': 8, 'HeiLongJiang': 12}
# {'GuangDong': 9, 'ShanDong': 8, 'ZheJiang': 8, 'LiaoNing': 8, 'HeiLongJiang': 12}

# %% [markdown]
# ### 7.2 Warnings on Using Dictionary Comprehension
# Even though dictionary comprehensions are great for writing elegant code that is easy to read, they are not always the right choice.
#
# We must be careful while using them as :
#
# * They can sometimes make the code run slower and consume more memory.
# * They can also decrease the readability of the code.
#
# We must not try to fit a difficult logic or a large number of dictionary comprehension inside them just for the sake of making the code single lined. In these cases, It is better to choose other alternatives like loops.

# %% [markdown]
# ## 8. Comparison of List and Dictionary
# | List | Dictionary |
# | ---- | ------- |
# | Ordered Sequence of elements | Matching Key and Values |
# | Index must be an integer | Key can be any immutable type |
# | Indices has an order | No order is guaranteed |
# | Search element by index | Search value by the key |
#
#
# **Task 4:** Complete the function `translate` that accepts two arguments: a dictionary that hold some English words and their corresponding Chinese words, and a sentence in English. The function should translate the sentence into Chinese and return the Chinese string. If a word in the sentence does not exist in the dictionary, `translate` will skip it.
#
# You can assume that:
#
# * the input sentence contains just words seperated by spaces
# * the dictionary is case insensitive and all the words in the dictionary is in lower case

# %%
def translate(dic, sentenceEN):
    s = sentenceEN.lower().split()
    res = [dic[x] for x in s if x in dic]
    return "".join(res)

# %%
dic = {'i': '我', 'you': '你', 'love': '爱', 'china': '中国', 'kunshan': '昆山', 'and': '和', 'he': '他', 'she': '她'}
assert translate(dic, 'I love China') == '我爱中国'
assert translate(dic, 'I love China which covers Kunshan') == '我爱中国昆山'

# %%
# This cell contains hidden tests. Do NOT delete!

# %%
# This cell contains hidden tests. Do NOT delete!

# %% [markdown]
# **Task 5:** Complete the function `validages` that accepts a list of tuples containing `(name, age)`, and returns a dictionary containing all the valid `name: age` records.
#
# Note that an age is valid if it's in `[0, 150]`. You may assume that the names are unique.
#
# Note: the body of your function MUST contain **only one line** of statement including the return statement.

# %%
def validages(nameages):
    return {name: age for name, age in nameages if 0 <= age <= 150}

# %%
assert validages([('Ann', 15), ('Bin', 190), ('Jack', 75)]) == {'Ann': 15, 'Jack': 75}
assert validages([('Ann', -15), ('Bin', 190), ('Jack', 0)]) == {'Jack': 0}
assert validages([('Ann', -15), ('Bin', 190)]) == {}

# %%
# This cell contains hidden tests. Do NOT delete!

# %%
# This cell contains hidden tests. Do NOT delete!

# %%
# This cell contains hidden tests. Do NOT delete!
