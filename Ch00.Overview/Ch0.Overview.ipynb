# %%
NAME = "Bohan YANG"
StudentID = "2330016056"

# %% [markdown]
# ---

# %% [markdown]
# # Overview
#
# *© 2018-current, authors at Computer Science and Technology, Division of Science and Technology, BNU-HKBU United International College*

# %% [markdown]
# ## What is Python?
# Python is
#
# <img src="img/ch0.boa.png" style="width: 150px;"/>
#
# but is better known as
#
# ![The Python Logo](img/ch0.python.logo.svg)
#
# At CST, Python is a
#
# * **general purpose**
#     * can be used for almost everything
# * **interpreted**
#     * codes are executed on the fly
#     * no compiling or executable files
# * **object-oriented**
#     * like Java!
#
# programming language. It was created by *Guido van Rossum* and was released in 1991.
#
# Python source code is available under the *GNU General Public License* (GPL).

# %% [markdown]
# ## Why Python?
#
# * It is **SIMPLE**.
#     * very few keywords
#     * clearly defined syntax
#     * easy to learn, easy to use, easy to read
#
# * It offers **rich library**
#     * big data analytics
#     * web frameworks
#     * testing tools
#     * ......
#
# * It is **POPULAR**!
#     * the top 5 language in almost every ranking
#         * [IEEE Ranking](https://spectrum.ieee.org/computing/software/the-2017-top-programming-languages): No.1
#         * [RedMonk's](https://redmonk.com/sogrady/2017/03/17/language-rankings-1-17/): No.3
#         * [The TIOBE Index](https://www.tiobe.com/tiobe-index/): No.4
#         * [The PopularitY of Programming Language (PYPL)](http://pypl.github.io/PYPL.html): No. 2
#
#     * Many famous web applications are written in Python
#
# <img src="img/new-youtube-logo.jpg" width = "100" height = "150"/>  |  <img src="img/Douban_logo.svg.png" width = "100" height = "150"/>  |  <img src="img/dropbox.png" width = "100" height = "150"/> |  <img src="img/quora.png" width = "100" height = "150"/> |  <img src="img/instagram-logo.png" width = "100" height = "150"/>|  <img src="img/spotify.png" width = "100" height = "150"/> |
# :-------------------------:|:-------------------------:|:-------------------------:|:-------------------------:|:-------------------------: |:-------------------------:
# Youtube |  豆瓣 |  Dropbox |  Quora |  Instagram |  Spotify |
#
# * Its **culture**
#     * The philosophy for Python, or, "Zen of Python", is shown when the interpreter executes "import this".

# %%
# Run me by hitting "Ctrl+Enter"
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# ## Course Information
#
# We are now in **Software Development Workshop II**
#
# | Section | Instructor | TA | Time | Venue |
# | ---- | ---- | ---- | ---- | ---- |
# | 1001 | Dr. Weipeng Zhuo | Ms. Shangyan Cai |  Thu 15:00 - 17:50 | T8-303 |
# | 1002 | Dr. Dyce Zhao | Ms. Yitong Liu |  Thu 8:00 - 10:50 | T8-303 |

# %% [markdown]
# ## Online Resources for Self Study
# * [Programiz](https://www.programiz.com/python-programming/) for **Python 3** learning
# * [Coder Byte](https://coderbyte.com/challenges) for exercises and **challenges**
